# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in d:\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: click in d:\anaconda3\lib\site-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in d:\anaconda3\lib\site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in d:\anaconda3\lib\site-packages (from nltk) (2025.9.1)
# Requirement already satisfied: tqdm in d:\anaconda3\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in d:\anaconda3\lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import nltk

from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer

# %%
nltk.download("punkt")
nltk.download("punkt_tab")
nltk.download("stopwords")
nltk.download("wordnet")
nltk.download("omw-1.4")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# True

# %%
df = pd.read_csv("clean_jobs.csv")

print("Rows:", len(df))
print("Columns:", len(df.columns))
# Out:
# Rows: 10100
# Columns: 12

# %%
df.head()
# Out:
#      job_id                  job_title               company        location  \
# 0  JOB07402         Frontend Developer  DataBridge Analytics  Gurgaon, India
# 1  JOB05835          Software Engineer        Vertex Digital   Mumbai, India
# 2  JOB02123  Machine Learning Engineer           CloudSphere   Mumbai, India
# 3  JOB08789             Cloud Engineer        Apex Solutions   Mumbai, India
# 4  JOB00305         Frontend Developer  Quantix Technologies    Noida, India
#
#                                      job_description experience  \
# 0  We are looking for a Frontend Developer to joi...  1-3 years
# 1  We are looking for a Software Engineer to join...  3-5 years
# 2  We are looking for a Machine Learning Engineer...  1-3 years
# 3  We are looking for a Cloud Engineer to join ou...  3-5 years
# 4  We are looking for a Frontend Developer to joi...  3-5 years
#
#            education     salary    job_type  \
# 0               B.E.   9-14 LPA   Full-time
# 1  Bachelor's Degree  12-16 LPA  Internship
# 2               B.E.   8-11 LPA   Full-time
# 3    Master's Degree  11-16 LPA   Full-time
# 4             B.Tech  10-12 LPA   Full-time
#
#                                    clean_description  original_length  \
# 0  we are looking for a frontend developer to joi...              362
# 1  we are looking for a software engineer to join...              342
# 2  we are looking for a machine learning engineer...              364
# 3  we are looking for a cloud engineer to join ou...              361
# 4  we are looking for a frontend developer to joi...              366
#
#    clean_length
# 0           351
# 1           333
# 2           354
# 3           350
# 4           355

# %%
text = df["clean_description"].iloc[0]

print(text)
# Out:
# we are looking for a frontend developer to join our team the candidate should have experience with git html typescript react css and javascript the role involves developing solutions analyzing requirements collaborating with cross functional teams and maintaining high quality deliverables strong problem solving and communication skills are preferred

# %%
text = text.lower()

print(text)
# Out:
# we are looking for a frontend developer to join our team the candidate should have experience with git html typescript react css and javascript the role involves developing solutions analyzing requirements collaborating with cross functional teams and maintaining high quality deliverables strong problem solving and communication skills are preferred

# %%
tokens = word_tokenize(text)

print(tokens)
# Out:
# ['we', 'are', 'looking', 'for', 'a', 'frontend', 'developer', 'to', 'join', 'our', 'team', 'the', 'candidate', 'should', 'have', 'experience', 'with', 'git', 'html', 'typescript', 'react', 'css', 'and', 'javascript', 'the', 'role', 'involves', 'developing', 'solutions', 'analyzing', 'requirements', 'collaborating', 'with', 'cross', 'functional', 'teams', 'and', 'maintaining', 'high', 'quality', 'deliverables', 'strong', 'problem', 'solving', 'and', 'communication', 'skills', 'are', 'preferred']

# %%
stop_words = set(stopwords.words("english"))

filtered_words = []

for word in tokens:
    if word not in stop_words:
        filtered_words.append(word)

print(filtered_words)
# Out:
# ['looking', 'frontend', 'developer', 'join', 'team', 'candidate', 'experience', 'git', 'html', 'typescript', 'react', 'css', 'javascript', 'role', 'involves', 'developing', 'solutions', 'analyzing', 'requirements', 'collaborating', 'cross', 'functional', 'teams', 'maintaining', 'high', 'quality', 'deliverables', 'strong', 'problem', 'solving', 'communication', 'skills', 'preferred']

# %%
lemmatizer = WordNetLemmatizer()

lemmatized_words = []

for word in filtered_words:
    lemmatized_words.append(
        lemmatizer.lemmatize(word)
    )

print(lemmatized_words)
# Out:
# ['looking', 'frontend', 'developer', 'join', 'team', 'candidate', 'experience', 'git', 'html', 'typescript', 'react', 'cs', 'javascript', 'role', 'involves', 'developing', 'solution', 'analyzing', 'requirement', 'collaborating', 'cross', 'functional', 'team', 'maintaining', 'high', 'quality', 'deliverable', 'strong', 'problem', 'solving', 'communication', 'skill', 'preferred']

# %%
stemmer = PorterStemmer()

stemmed_words = []

for word in filtered_words:
    stemmed_words.append(
        stemmer.stem(word)
    )

print(stemmed_words)
# Out:
# ['look', 'frontend', 'develop', 'join', 'team', 'candid', 'experi', 'git', 'html', 'typescript', 'react', 'css', 'javascript', 'role', 'involv', 'develop', 'solut', 'analyz', 'requir', 'collabor', 'cross', 'function', 'team', 'maintain', 'high', 'qualiti', 'deliver', 'strong', 'problem', 'solv', 'commun', 'skill', 'prefer']

# %%
words = [
    "running",
    "studies",
    "playing",
    "developers"
]

for word in words:

    stem = stemmer.stem(word)
    lemma = lemmatizer.lemmatize(word)

    print("Word:", word)
    print("Stem:", stem)
    print("Lemma:", lemma)
    print()
# Out:
# Word: running
# Stem: run
# Lemma: running
#
# Word: studies
# Stem: studi
# Lemma: study
#
# Word: playing
# Stem: play
# Lemma: playing
#
# Word: developers
# Stem: develop
# Lemma: developer

# %%
sentences = sent_tokenize(text)

for sentence in sentences:
    print(sentence)
# Out:
# we are looking for a frontend developer to join our team the candidate should have experience with git html typescript react css and javascript the role involves developing solutions analyzing requirements collaborating with cross functional teams and maintaining high quality deliverables strong problem solving and communication skills are preferred

# %%
def preprocess_text(text):

    # Lowercase
    text = text.lower()

    # Tokenization
    tokens = word_tokenize(text)

    # Remove stopwords
    tokens = [
        word for word in tokens
        if word not in stop_words
    ]

    # Lemmatization
    tokens = [
        lemmatizer.lemmatize(word)
        for word in tokens
    ]

    return tokens

# %%
result = preprocess_text(
    df["clean_description"].iloc[0]
)

print(result)
# Out:
# ['looking', 'frontend', 'developer', 'join', 'team', 'candidate', 'experience', 'git', 'html', 'typescript', 'react', 'cs', 'javascript', 'role', 'involves', 'developing', 'solution', 'analyzing', 'requirement', 'collaborating', 'cross', 'functional', 'team', 'maintaining', 'high', 'quality', 'deliverable', 'strong', 'problem', 'solving', 'communication', 'skill', 'preferred']

# %%
df["processed_text"] = df["clean_description"].apply(
    preprocess_text
)

# %%
df[[
    "job_title",
    "clean_description",
    "processed_text"
]].head()
# Out:
#                    job_title  \
# 0         Frontend Developer
# 1          Software Engineer
# 2  Machine Learning Engineer
# 3             Cloud Engineer
# 4         Frontend Developer
#
#                                    clean_description  \
# 0  we are looking for a frontend developer to joi...
# 1  we are looking for a software engineer to join...
# 2  we are looking for a machine learning engineer...
# 3  we are looking for a cloud engineer to join ou...
# 4  we are looking for a frontend developer to joi...
#
#                                       processed_text
# 0  [looking, frontend, developer, join, team, can...
# 1  [looking, software, engineer, join, team, cand...
# 2  [looking, machine, learning, engineer, join, t...
# 3  [looking, cloud, engineer, join, team, candida...
# 4  [looking, frontend, developer, join, team, can...

# %%
df.to_csv(
    "preprocessed_jobs.csv",
    index=False
)

print("Preprocessing completed successfully!")
# Out:
# Preprocessing completed successfully!
