# %%
import pandas as pd

# %%
skills = [
    ["Python", "Programming", "python3, python"],
    ["Java", "Programming", "java"],
    ["C++", "Programming", "c++, cpp"],
    ["JavaScript", "Programming", "javascript, js"],
    
    ["SQL", "Database", "sql"],
    ["MySQL", "Database", "mysql"],
    ["PostgreSQL", "Database", "postgres, postgresql"],
    ["MongoDB", "Database", "mongodb, mongo"],
    
    ["Power BI", "Data Analytics", "powerbi, power-bi, power bi"],
    ["Tableau", "Data Analytics", "tableau"],
    ["Excel", "Data Analytics", "excel, ms excel"],
    
    ["Pandas", "Data Science", "pandas"],
    ["NumPy", "Data Science", "numpy"],
    
    ["Scikit-learn", "Machine Learning", "scikit learn, sklearn, scikit-learn"],
    ["TensorFlow", "Machine Learning", "tensorflow"],
    ["PyTorch", "Machine Learning", "pytorch"],
    
    ["AWS", "Cloud", "aws"],
    ["Azure", "Cloud", "azure"],
    ["GCP", "Cloud", "gcp, google cloud"],
    
    ["Spark", "Big Data", "spark, apache spark"],
    ["Hadoop", "Big Data", "hadoop, apache hadoop"],
    
    ["Docker", "DevOps", "docker"],
    ["Kubernetes", "DevOps", "kubernetes, k8s"],
    ["Git", "Version Control", "git"]
]

# %%
skill_df = pd.DataFrame(
    skills,
    columns=["skill", "category", "aliases"]
)

skill_df
# Out:
#            skill          category                              aliases
# 0         Python       Programming                      python3, python
# 1           Java       Programming                                 java
# 2            C++       Programming                             c++, cpp
# 3     JavaScript       Programming                       javascript, js
# 4            SQL          Database                                  sql
# 5          MySQL          Database                                mysql
# 6     PostgreSQL          Database                 postgres, postgresql
# 7        MongoDB          Database                       mongodb, mongo
# 8       Power BI    Data Analytics          powerbi, power-bi, power bi
# 9        Tableau    Data Analytics                              tableau
# 10         Excel    Data Analytics                      excel, ms excel
# 11        Pandas      Data Science                               pandas
# 12         NumPy      Data Science                                numpy
# 13  Scikit-learn  Machine Learning  scikit learn, sklearn, scikit-learn
# 14    TensorFlow  Machine Learning                           tensorflow
# 15       PyTorch  Machine Learning                              pytorch
# 16           AWS             Cloud                                  aws
# 17         Azure             Cloud                                azure
# 18           GCP             Cloud                    gcp, google cloud
# 19         Spark          Big Data                  spark, apache spark
# 20        Hadoop          Big Data                hadoop, apache hadoop
# 21        Docker            DevOps                               docker
# 22    Kubernetes            DevOps                      kubernetes, k8s
# 23           Git   Version Control                                  git

# %%
skill_df["category"].value_counts()
# Out:
# category
# Programming         4
# Database            4
# Data Analytics      3
# Machine Learning    3
# Cloud               3
# Data Science        2
# Big Data            2
# DevOps              2
# Version Control     1
# Name: count, dtype: int64

# %%
print("Total skills:", len(skill_df))
# Out:
# Total skills: 24

# %%
skill_df[skill_df["category"] == "Programming"]
# Out:
#         skill     category          aliases
# 0      Python  Programming  python3, python
# 1        Java  Programming             java
# 2         C++  Programming         c++, cpp
# 3  JavaScript  Programming   javascript, js

# %%
skill_df[skill_df["category"] == "Database"]

# %%
skill_df.to_csv("skill_taxonomy.csv", index=False)

print("Skill taxonomy saved successfully!")
# Out:
# Skill taxonomy saved successfully!

# %%
day
