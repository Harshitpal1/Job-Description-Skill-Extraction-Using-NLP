# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv("raw_jobs_10k.csv")
# Out:
#          job_id                  job_title               company  \
# 0      JOB07402         Frontend Developer  DataBridge Analytics
# 1      JOB05835          Software Engineer        Vertex Digital
# 2      JOB02123  Machine Learning Engineer           CloudSphere
# 3      JOB08789             Cloud Engineer        Apex Solutions
# 4      JOB00305         Frontend Developer  Quantix Technologies
# ...         ...                        ...                   ...
# 10095  JOB05735             Data Scientist    BlueOrbit Software
# 10096  JOB05192  Machine Learning Engineer           CloudSphere
# 10097  JOB05391             Data Scientist       CodeCraft India
# 10098  JOB00861               Data Analyst           CloudSphere
# 10099  JOB07271  Machine Learning Engineer    TechNova Solutions
#
#              location                                    job_description  \
# 0      Gurgaon, India  We are looking for a Frontend Developer to joi...
# ...

# %% [markdown]
# #**EDA**

# %% [markdown]
# **Overview and Inspection Commands**

# %%
df=pd.read_csv("raw_jobs_10k.csv")

# %%
len(df)
# Out:
# 10100

# %%
df.shape
# Out:
# (10100, 9)

# %%
df.dtypes
# Out:
# job_id             object
# job_title          object
# company            object
# location           object
# job_description    object
# experience         object
# education          object
# salary             object
# job_type           object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10100 entries, 0 to 10099
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   job_id           10100 non-null  object
#  1   job_title        10100 non-null  object
#  2   company          10100 non-null  object
#  3   location         10020 non-null  object
#  4   job_description  10100 non-null  object
#  5   experience       10100 non-null  object
#  6   education        9979 non-null   object
#  7   salary           9899 non-null   object
#  8   job_type         10100 non-null  object
# dtypes: object(9)
# memory usage: 710.3+ KB

# %%
df.head()
# Out:
#      job_id                  job_title               company        location  \
# 0  JOB07402         Frontend Developer  DataBridge Analytics  Gurgaon, India
# 1  JOB05835          Software Engineer        Vertex Digital   Mumbai, India
# 2  JOB02123  Machine Learning Engineer           CloudSphere   Mumbai, India
# 3  JOB08789             Cloud Engineer        Apex Solutions   Mumbai, India
# 4  JOB00305         Frontend Developer  Quantix Technologies    Noida, India
#
#                                      job_description experience  \
# 0  We are looking for a Frontend Developer to joi...  1-3 years
# 1  We are looking for a Software Engineer to join...  3-5 years
# 2  We are looking for a Machine Learning Engineer...  1-3 years
# 3  We are looking for a Cloud Engineer to join ou...  3-5 years
# 4  We are looking for a Frontend Developer to joi...  3-5 years
#
#            education     salary    job_type
# 0               B.E.   9-14 LPA   Full-time
# ...

# %%
df.tail()
# Out:
#          job_id                  job_title             company  \
# 10095  JOB05735             Data Scientist  BlueOrbit Software
# 10096  JOB05192  Machine Learning Engineer         CloudSphere
# 10097  JOB05391             Data Scientist     CodeCraft India
# 10098  JOB00861               Data Analyst         CloudSphere
# 10099  JOB07271  Machine Learning Engineer  TechNova Solutions
#
#              location                                    job_description  \
# 10095    Noida, India  We are looking for a Data Scientist to join ou...
# 10096   Mumbai, India  We are looking for a Machine Learning Engineer...
# 10097  Gwalior, India  We are looking for a Data Scientist to join ou...
# 10098          Remote  We are looking for a Data Analyst to join our ...
# 10099    Noida, India  We are looking for a Machine Learning Engineer...
#
#       experience        education    salary    job_type
# 10095  3-5 years    B.Tech/M.Tech  7-10 LPA   Full-time
# ...

# %%
df.sample(5)
# Out:
#         job_id           job_title               company          location  \
# 670   JOB06881   Software Engineer  FinEdge Technologies       Pune, India
# 4755  JOB00979      Cloud Engineer             NexaWorks  Bangalore, India
# 6509  JOB03172         QA Engineer        Apex Solutions    Gurgaon, India
# 126   JOB01531  Frontend Developer       CodeCraft India  Hyderabad, India
# 1495  JOB06171      Cloud Engineer  FinEdge Technologies  Hyderabad, India
#
#                                         job_description experience  \
# 670   We are looking for a Software Engineer to join...  5-8 years
# 4755  We are looking for a Cloud Engineer to join ou...  2-4 years
# 6509  We are looking for a QA Engineer to join our t...  5-8 years
# 126   We are looking for a Frontend Developer to joi...  5-8 years
# 1495  We are looking for a Cloud Engineer to join ou...  1-3 years
#
#               education     salary   job_type
# 670   Bachelor's Degree  10-13 LPA   Contract
# ...

# %% [markdown]
# **Statistics and Counts**

# %%
df.describe()
# Out:
#           job_id       job_title      company        location  \
# count      10100           10100        10100           10020
# unique     10000              10           12              10
# top     JOB01720  Cloud Engineer  CloudSphere  Chennai, India
# freq           2            1044          884            1024
#
#                                           job_description experience  \
# count                                               10100      10100
# unique                                               8908          5
# top     We are looking for a Business Analyst to join ...  2-4 years
# freq                                                    5       2055
#
#               education   salary   job_type
# count              9979     9899      10100
# unique                5       40          4
# top     Master's Degree  6-9 LPA  Full-time
# freq               2101      391       7094

# %%
df.nunique()
# Out:
# job_id             10000
# job_title             10
# company               12
# location              10
# job_description     8908
# experience             5
# education              5
# salary                40
# job_type               4
# dtype: int64

# %%
df['job_title'].value_counts()
# Out:
# job_title
# Cloud Engineer               1044
# Business Analyst             1044
# Backend Developer            1040
# QA Engineer                  1038
# Data Analyst                 1027
# Software Engineer            1002
# Machine Learning Engineer     991
# Frontend Developer            978
# DevOps Engineer               969
# Data Scientist                967
# Name: count, dtype: int64

# %% [markdown]
# **Missing values and Duplicates**

# %%
df.isnull().sum()
# Out:
# job_id               0
# job_title            0
# company              0
# location            80
# job_description      0
# experience           0
# education          121
# salary             201
# job_type             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(100)

# %% [markdown]
# #**Data Cleaning**

# %% [markdown]
# **Conditional Filtering**

# %%
df[df['job_type'] == 'Full-Time']
# Out:
# Empty DataFrame
# Columns: [job_id, job_title, company, location, job_description, experience, education, salary, job_type]
# Index: []

# %%
df[df['job_type'].str.contains('full-Time', case=False, na=False)]
# Out:
#          job_id                  job_title               company  \
# 0      JOB07402         Frontend Developer  DataBridge Analytics
# 2      JOB02123  Machine Learning Engineer           CloudSphere
# 3      JOB08789             Cloud Engineer        Apex Solutions
# 4      JOB00305         Frontend Developer  Quantix Technologies
# 5      JOB02532               Data Analyst             NexaWorks
# ...         ...                        ...                   ...
# 10092  JOB04427  Machine Learning Engineer  Quantix Technologies
# 10093  JOB00467         Frontend Developer             NexaWorks
# 10095  JOB05735             Data Scientist    BlueOrbit Software
# 10097  JOB05391             Data Scientist       CodeCraft India
# 10099  JOB07271  Machine Learning Engineer    TechNova Solutions
#
#                location                                    job_description  \
# 0        Gurgaon, India  We are looking for a Frontend Developer to joi...
# ...

# %%
(df.isnull().sum() / len(df)) * 100
# Out:
# job_id                0.000000
# job_title             0.000000
# company               0.000000
# location              0.792079
# job_description       0.000000
# experience            0.000000
# education             1.198020
# salary                1.990099
# job_type              0.000000
# description_length    0.000000
# dtype: float64

# %%
df['job_description'].str.len
# Out:
# <bound method StringMethods.len of <pandas.core.strings.accessor.StringMethods object at 0x000001BD1E2D3360>>

# %%
df["description_length"] = df["job_description"].str.len()

# %%
df["description_length"].describe()
# Out:
# count    10100.000000
# mean       355.154356
# std         10.307320
# min        330.000000
# 25%        348.000000
# 50%        355.000000
# 75%        362.000000
# max        378.000000
# Name: description_length, dtype: float64

# %%
df["description_length"].describe()
# Out:
# count    10100.000000
# mean       355.154356
# std         10.307320
# min        330.000000
# 25%        348.000000
# 50%        355.000000
# 75%        362.000000
# max        378.000000
# Name: description_length, dtype: float64

# %%
df["job_title"].value_counts().head(10)
